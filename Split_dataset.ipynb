# %% [markdown]
# <a href="https://colab.research.google.com/github/malihasama07/ML-AI/blob/main/Split_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Final_1_Emotion/shuffled_preprocessed_dataset.csv')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Step 1: Split to Train (70%) and Temp (30%)
train_df, temp_df = train_test_split(df, test_size=0.30, random_state=42, shuffle=True)

# Step 2: Split Temp into Validation (15%) and Test (15%)
# Since temp is 30% of total, half of it = 15%
val_df, test_df = train_test_split(temp_df, test_size=0.50, random_state=42, shuffle=True)

# Save files
train_df.to_csv("train.csv", index=False)
val_df.to_csv("val.csv", index=False)
test_df.to_csv("test.csv", index=False)

print("Dataset Splitted Successfully ")
print("Train:", train_df.shape)
print("Validation:", val_df.shape)
print("Test:", test_df.shape)
# Out:
# Dataset Splitted Successfully
# Train: (19466, 12)
# Validation: (4171, 12)
# Test: (4172, 12)

# %%
from google.colab import files

files.download("train.csv")
